# %%
# !pip install torch==2.1.2
# !pip install torchvision==0.16.2
# !pip install numpy==1.26.4
# !pip install openmim
# !mim install mmengine
# !mim install "mmcv==2.1.0"
# !mim install mmdet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 84.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 67.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 5.9 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/khanhtran2101/Multi_Domain_Learning_Malaria_Parasite
# %cd Multi_Domain_Learning_Malaria_Parasite
# !mim install -e .
# Out:
# Cloning into 'Multi_Domain_Learning_Malaria_Parasite'...
# remote: Enumerating objects: 16727, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 16727 (delta 4), reused 11 (delta 0), pack-reused 16709 (from 1)
# Receiving objects: 100% (16727/16727), 13.51 MiB | 31.65 MiB/s, done.
# Resolving deltas: 100% (11700/11700), done.
# /kaggle/working/Multi_Domain_Learning_Malaria_Parasite
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Obtaining file:///kaggle/working/Multi_Domain_Learning_Malaria_Parasite
# done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 101.5 kB/s eta 0:00:00
# ...
#   Running setup.py develop for mmpretrain
# ...

# %%
# !python tools/train.py /kaggle/input/configs-file/baseline1_ourdata_mmpretrain_kaggle_Nov18.py
# Out:
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# 11/18 09:31:00 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1371632078
#     GPU 0: Tesla P100-PCIE-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.2+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
# ...

# %%
# !python tools/test.py /kaggle/input/configs-file/original_openmm_kaggle_Nov18.py /kaggle/working/experiment_result/epoch_50.pth
# Out:
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# 11/18 09:31:26 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1624544930
#     GPU 0: Tesla P100-PCIE-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.2+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
# ...
