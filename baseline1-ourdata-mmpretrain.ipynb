# %%
# !pip install torch==2.1.2
# !pip install torchvision==0.16.2
# !pip install numpy==1.26.4
# !pip install openmim
# !mim install mmengine
# !mim install "mmcv==2.1.0"
# !mim install mmdet
# Out:
# Collecting torch==2.1.2
#   Downloading torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1.2)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1.2)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1.2)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1.2)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1.2)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1.2)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1.2)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1.2)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1.2)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1.2)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1.2)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.1.0 (from torch==2.1.2)
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2)
#   Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.1.2) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.1.2) (1.3.0)
# Downloading torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 85.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 72.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 40.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 30.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.0 MB/s eta 0:00:00
# Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 18.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 76.5 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.6.77 nvidia-nvtx-cu12-12.1.105 torch-2.1.2 triton-2.1.0
# Collecting torchvision==0.16.2
#   Downloading torchvision-0.16.2-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.16.2) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.16.2) (2.32.3)
# Requirement already satisfied: torch==2.1.2 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.16.2) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.16.2) (10.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchvision==0.16.2) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.2->torchvision==0.16.2) (12.6.77)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.16.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.16.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.16.2) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.16.2) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.1.2->torchvision==0.16.2) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.1.2->torchvision==0.16.2) (1.3.0)
# Downloading torchvision-0.16.2-cp310-cp310-manylinux1_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 60.0 MB/s eta 0:00:00
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0
#     Uninstalling torchvision-0.19.0:
#       Successfully uninstalled torchvision-0.19.0
# Successfully installed torchvision-0.16.2
# Requirement already satisfied: numpy==1.26.4 in /opt/conda/lib/python3.10/site-packages (1.26.4)
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /opt/conda/lib/python3.10/site-packages (from openmim) (8.1.7)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from openmim) (0.4.6)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from openmim) (2.2.2)
# Requirement already satisfied: pip>=19.3 in /opt/conda/lib/python3.10/site-packages (from openmim) (24.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from openmim) (2.32.3)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from openmim) (13.7.1)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /opt/conda/lib/python3.10/site-packages (from model-index->openmim) (3.6)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pycryptodome in /opt/conda/lib/python3.10/site-packages (from opendatalab->openmim) (3.20.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from opendatalab->openmim) (4.66.4)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->openmim) (2024.8.30)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->openmim) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->openmim) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.16.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 9.0 MB/s eta 0:00:00
# done
# Collecting packaging~=24.0 (from openxlab->opendatalab->openmim)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: crcmod>=1.7 in /opt/conda/lib/python3.10/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 23.3 MB/s eta 0:00:00
# done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (42.0.8)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.6 MB/s eta 0:00:00
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.2-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 18.4 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.7 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 14.3 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 28.9 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 5.0 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.3 MB/s eta 0:00:00
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 47.8 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 7.6 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core
# done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=0a75b507c7c2e45d04e05626c33aba9d606b49b6fc6a5aa72cc0af004107db36
#   Stored in directory: /root/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
# done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535317 sha256=e551d0f30e800e0877dc9a87891c8c4b95e7b7a54a4d8037e54d7282c3143072
#   Stored in directory: /root/.cache/pip/wheels/35/11/5e/08e7cb4e03a3e83b4862edd12d1143c8d3936a3dd57a3ee46d
# Successfully built oss2 aliyun-python-sdk-core
# Installing collected packages: pytz, tqdm, setuptools, requests, packaging, ordered-set, jmespath, filelock, rich, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 70.0.0
#     Uninstalling setuptools-70.0.0:
#       Successfully uninstalled setuptools-70.0.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 1.0.1
#     Uninstalling jmespath-1.0.1:
#       Successfully uninstalled jmespath-1.0.1
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.15.1
#     Uninstalling filelock-3.15.1:
#       Successfully uninstalled filelock-3.15.1
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.8.3 requires cubinlinker, which is not installed.
# cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 24.8.3 requires ptxcompiler, which is not installed.
# cuml 24.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 24.8.3 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires cloudpickle~=2.2.1, but you have cloudpickle 3.0.0 which is incompatible.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.8 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 16.1.0 which is incompatible.
# beatrix-jupyterlab 2024.66.154055 requires jupyterlab~=3.6.0, but you have jupyterlab 4.2.5 which is incompatible.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# bigframes 0.22.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.2 which is incompatible.
# boto3 1.26.100 requires botocore<1.30.0,>=1.29.100, but you have botocore 1.35.23 which is incompatible.
# cudf 24.8.3 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# dataproc-jupyter-plugin 0.1.79 requires pydantic~=1.10.0, but you have pydantic 2.9.2 which is incompatible.
# datasets 3.0.1 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 3.0.1 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# distributed 2024.7.1 requires dask==2024.7.1, but you have dask 2024.9.1 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# google-cloud-aiplatform 0.6.0a1 requires google-api-core[grpc]<2.0.0dev,>=1.22.2, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-automl 1.0.1 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.11.1 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 24.2 which is incompatible.
# ibis-framework 7.1.0 requires pyarrow<15,>=2, but you have pyarrow 16.1.0 which is incompatible.
# jupyterlab 4.2.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.1.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-server 2.27.2 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# kfp 2.5.0 requires google-cloud-storage<3,>=2.2.1, but you have google-cloud-storage 1.44.0 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# rapids-dask-dependency 24.8.0a0 requires dask==2024.7.1, but you have dask 2024.9.1 which is incompatible.
# ydata-profiling 4.10.0 requires scipy<1.14,>=1.4.1, but you have scipy 1.14.1 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.2 ordered-set-4.1.0 oss2-2.17.0 packaging-24.2 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.10.5-py3-none-any.whl.metadata (20 kB)
# Collecting addict (from mmengine)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmengine) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmengine) (1.26.4)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from mmengine) (6.0.2)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from mmengine) (2.4.0)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from mmengine) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.10/site-packages (from mmengine) (4.10.0.84)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine) (2.18.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmengine) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmengine) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Downloading mmengine-0.10.5-py3-none-any.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.3/452.3 kB 11.3 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: addict, mmengine
# Successfully installed addict-2.4.0 mmengine-0.10.5
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Collecting mmcv==2.1.0
#   Downloading https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/mmcv-2.1.0-cp310-cp310-manylinux1_x86_64.whl (94.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.1/94.1 MB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: addict in /opt/conda/lib/python3.10/site-packages (from mmcv==2.1.0) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from mmcv==2.1.0) (0.10.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmcv==2.1.0) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from mmcv==2.1.0) (24.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from mmcv==2.1.0) (10.3.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from mmcv==2.1.0) (6.0.2)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from mmcv==2.1.0) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.10/site-packages (from mmcv==2.1.0) (4.10.0.84)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.7.5)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.3.0->mmcv==2.1.0) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from mmengine>=0.3.0->mmcv==2.1.0) (2.4.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.1.0) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.1.0) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv==2.1.0) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv==2.1.0) (3.19.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.1.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.1.0
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Collecting mmdet
#   Downloading mmdet-3.3.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmdet) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmdet) (1.26.4)
# Collecting pycocotools (from mmdet)
#   Downloading pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from mmdet) (1.14.1)
# Requirement already satisfied: shapely in /opt/conda/lib/python3.10/site-packages (from mmdet) (1.8.5.post1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from mmdet) (1.16.0)
# Collecting terminaltables (from mmdet)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from mmdet) (4.65.2)
# Requirement already satisfied: mmcv<2.2.0,>=2.0.0rc4 in /opt/conda/lib/python3.10/site-packages (from mmdet) (2.1.0)
# Requirement already satisfied: mmengine<1.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from mmdet) (0.10.5)
# Requirement already satisfied: addict in /opt/conda/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (2.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (24.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (10.3.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (6.0.2)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.10/site-packages (from mmcv<2.2.0,>=2.0.0rc4->mmdet) (4.10.0.84)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from mmengine<1.0.0,>=0.7.1->mmdet) (13.4.2)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from mmengine<1.0.0,>=0.7.1->mmdet) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmdet) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine<1.0.0,>=0.7.1->mmdet) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmengine<1.0.0,>=0.7.1->mmdet) (2.18.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0rc4->mmdet) (7.0.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0rc4->mmdet) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv<2.2.0,>=2.0.0rc4->mmdet) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->mmcv<2.2.0,>=2.0.0rc4->mmdet) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmengine<1.0.0,>=0.7.1->mmdet) (0.1.2)
# Downloading mmdet-3.3.0-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 35.0 MB/s eta 0:00:00
# Downloading pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.8/427.8 kB 26.0 MB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables, pycocotools, mmdet
# Successfully installed mmdet-3.3.0 pycocotools-2.0.8 terminaltables-3.1.10

# %%
# !git clone https://github.com/khanhtran2101/Multi_Domain_Learning_Malaria_Parasite
# %cd Multi_Domain_Learning_Malaria_Parasite
# !mim install -e .
# Out:
# Cloning into 'Multi_Domain_Learning_Malaria_Parasite'...
# remote: Enumerating objects: 16733, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 16733 (delta 74), reused 111 (delta 48), pack-reused 16561 (from 1)
# Receiving objects: 100% (16733/16733), 13.56 MiB | 23.86 MiB/s, done.
# Resolving deltas: 100% (11658/11658), done.
# /kaggle/working/Multi_Domain_Learning_Malaria_Parasite
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu121/torch2.1.0/index.html
# Obtaining file:///kaggle/working/Multi_Domain_Learning_Malaria_Parasite
# done
# Collecting einops (from mmpretrain==1.2.0)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.10/site-packages (from mmpretrain==1.2.0) (7.0.0)
# Collecting mat4py (from mmpretrain==1.2.0)
#   Downloading mat4py-0.6.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from mmpretrain==1.2.0) (3.7.5)
# Collecting modelindex (from mmpretrain==1.2.0)
#   Downloading modelindex-0.0.2-py3-none-any.whl.metadata (756 bytes)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from mmpretrain==1.2.0) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from mmpretrain==1.2.0) (13.4.2)
# Requirement already satisfied: mmcv<2.4.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from mmpretrain==1.2.0) (2.1.0)
# Requirement already satisfied: mmengine<1.0.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from mmpretrain==1.2.0) (0.10.5)
# Requirement already satisfied: addict in /opt/conda/lib/python3.10/site-packages (from mmcv<2.4.0,>=2.0.0->mmpretrain==1.2.0) (2.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from mmcv<2.4.0,>=2.0.0->mmpretrain==1.2.0) (24.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from mmcv<2.4.0,>=2.0.0->mmpretrain==1.2.0) (10.3.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from mmcv<2.4.0,>=2.0.0->mmpretrain==1.2.0) (6.0.2)
# Requirement already satisfied: yapf in /opt/conda/lib/python3.10/site-packages (from mmcv<2.4.0,>=2.0.0->mmpretrain==1.2.0) (0.40.2)
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.10/site-packages (from mmcv<2.4.0,>=2.0.0->mmpretrain==1.2.0) (4.10.0.84)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from mmengine<1.0.0,>=0.8.3->mmpretrain==1.2.0) (2.4.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata->mmpretrain==1.2.0) (3.19.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmpretrain==1.2.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmpretrain==1.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmpretrain==1.2.0) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmpretrain==1.2.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmpretrain==1.2.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->mmpretrain==1.2.0) (2.9.0.post0)
# Requirement already satisfied: model-index in /opt/conda/lib/python3.10/site-packages (from modelindex->mmpretrain==1.2.0) (0.1.11)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmpretrain==1.2.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->mmpretrain==1.2.0) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mmpretrain==1.2.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->mmpretrain==1.2.0) (1.16.0)
# Requirement already satisfied: markdown in /opt/conda/lib/python3.10/site-packages (from model-index->modelindex->mmpretrain==1.2.0) (3.6)
# Requirement already satisfied: ordered-set in /opt/conda/lib/python3.10/site-packages (from model-index->modelindex->mmpretrain==1.2.0) (4.1.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from model-index->modelindex->mmpretrain==1.2.0) (8.1.7)
# Requirement already satisfied: platformdirs>=3.5.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv<2.4.0,>=2.0.0->mmpretrain==1.2.0) (3.11.0)
# Requirement already satisfied: tomli>=2.0.1 in /opt/conda/lib/python3.10/site-packages (from yapf->mmcv<2.4.0,>=2.0.0->mmpretrain==1.2.0) (2.0.1)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.0 MB/s eta 0:00:00
# Downloading mat4py-0.6.0-py2.py3-none-any.whl (13 kB)
# Downloading modelindex-0.0.2-py3-none-any.whl (2.1 kB)
# Installing collected packages: mat4py, einops, modelindex, mmpretrain
#   Running setup.py develop for mmpretrain
# Successfully installed einops-0.8.0 mat4py-0.6.0 mmpretrain-1.2.0 modelindex-0.0.2

# %%
# !python tools/train.py /kaggle/input/configs-file/baseline1_ourdata_mmpretrain_kaggle_Nov18.py
# Out:
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# 11/18 10:58:50 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1961182806
#     GPU 0: Tesla P100-PCIE-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.2+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.2, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.2+cu121
#     OpenCV: 4.10.0
#     MMEngine: 0.10.5
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1961182806
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/18 10:58:50 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=256)
# batch_size = 128
# data_root = '/kaggle/input/malaria-parasite/final_malaria_full_class_classification_cropped'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=True, interval=10, type='CheckpointHook'),
#     logger=dict(interval=100, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(enable=False, type='VisualizationHook'))
# default_scope = 'mmpretrain'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# model = dict(
#     backbone=dict(
#         depth=50,
#         init_cfg=dict(
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth',
#             prefix='backbone',
#             type='Pretrained'),
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch',
#         type='ResNet'),
#     data_preprocessor=dict(
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         to_rgb=True),
#     head=dict(
#         in_channels=2048,
#         loss=dict(loss_weight=1.0, type='CrossEntropyLoss'),
#         num_classes=6,
#         topk=(
#             1,
#             5,
#         ),
#         type='LinearClsHead'),
#     neck=dict(type='GlobalAveragePooling'),
#     type='ImageClassifier')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.0001, type='Adam', weight_decay=0.0001),
#     type='OptimWrapper')
# optimizer = dict(_delete_=True, lr=0.0001, type='Adam', weight_decay=0.0001)
# param_scheduler = dict(
#     by_epoch=True, gamma=0.1, milestones=[
#         25,
#     ], type='MultiStepLR')
# randomness = dict(deterministic=False, seed=None)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=128,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file='test_annotation.txt',
#         data_prefix='',
#         data_root=
#         '/kaggle/input/malaria-parasite/final_malaria_full_class_classification_cropped',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=224, type='Resize'),
#             dict(type='PackInputs'),
#         ],
#         type='CustomDataset',
#         with_label=True),
#     num_workers=1,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# test_evaluator = [
#     dict(type='Accuracy'),
#     dict(type='ConfusionMatrix'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(scale=224, type='Resize'),
#     dict(type='PackInputs'),
# ]
# train_cfg = dict(max_epochs=50, type='EpochBasedTrainLoop', val_interval=5)
# train_dataloader = dict(
#     batch_size=128,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file='train_annotation.txt',
#         data_prefix='',
#         data_root=
#         '/kaggle/input/malaria-parasite/final_malaria_full_class_classification_cropped',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 crop_ratio_range=(
#                     0.08,
#                     1.0,
#                 ),
#                 scale=224,
#                 type='RandomResizedCrop'),
#             dict(
#                 direction=[
#                     'horizontal',
#                     'vertical',
#                 ],
#                 prob=[
#                     0.25,
#                     0.25,
#                 ],
#                 type='RandomFlip'),
#             dict(type='PackInputs'),
#         ],
#         type='CustomDataset',
#         with_label=True),
#     num_workers=1,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(crop_ratio_range=(
#         0.08,
#         1.0,
#     ), scale=224, type='RandomResizedCrop'),
#     dict(
#         direction=[
#             'horizontal',
#             'vertical',
#         ],
#         prob=[
#             0.25,
#             0.25,
#         ],
#         type='RandomFlip'),
#     dict(type='PackInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=128,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file='val_annotation.txt',
#         data_prefix='',
#         data_root=
#         '/kaggle/input/malaria-parasite/final_malaria_full_class_classification_cropped',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=224, type='Resize'),
#             dict(type='PackInputs'),
#         ],
#         type='CustomDataset',
#         with_label=True),
#     num_workers=1,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# val_evaluator = [
#     dict(type='Accuracy'),
#     dict(type='ConfusionMatrix'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='Visualizer', vis_backends=[
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = '/kaggle/working/experiment_result'
#
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 11/18 10:59:08 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/18 10:59:08 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 11/18 10:59:10 - mmengine - INFO - load backbone in model from: https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# Downloading: "https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth" to /root/.cache/torch/hub/checkpoints/resnet50_8xb32_in1k_20210831-ea4938fc.pth
# 100%|██████████████████████████████████████| 97.8M/97.8M [00:06<00:00, 16.3MB/s]
# 11/18 10:59:16 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 11/18 10:59:16 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 11/18 10:59:16 - mmengine - INFO - Checkpoints will be saved to /kaggle/working/experiment_result.
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 11/18 11:01:07 - mmengine - INFO - Epoch(train)  [1][100/241]  lr: 1.0000e-04  eta: 3:39:59  time: 1.0966  data_time: 0.5142  memory: 10877  loss: 0.1265
# 11/18 11:02:53 - mmengine - INFO - Epoch(train)  [1][200/241]  lr: 1.0000e-04  eta: 3:34:05  time: 1.1090  data_time: 0.5265  memory: 10877  loss: 0.1196
# 11/18 11:03:38 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:04:36 - mmengine - INFO - Epoch(train)  [2][100/241]  lr: 1.0000e-04  eta: 3:03:02  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.1138
# 11/18 11:05:35 - mmengine - INFO - Epoch(train)  [2][200/241]  lr: 1.0000e-04  eta: 2:45:56  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0804
# 11/18 11:05:58 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:06:57 - mmengine - INFO - Epoch(train)  [3][100/241]  lr: 1.0000e-04  eta: 2:31:12  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0804
# 11/18 11:07:55 - mmengine - INFO - Epoch(train)  [3][200/241]  lr: 1.0000e-04  eta: 2:24:08  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0921
# 11/18 11:08:19 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:09:17 - mmengine - INFO - Epoch(train)  [4][100/241]  lr: 1.0000e-04  eta: 2:16:38  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0955
# 11/18 11:10:16 - mmengine - INFO - Epoch(train)  [4][200/241]  lr: 1.0000e-04  eta: 2:12:29  time: 0.5840  data_time: 0.0012  memory: 10877  loss: 0.0643
# 11/18 11:10:39 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:11:01 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:11:38 - mmengine - INFO - Epoch(train)  [5][100/241]  lr: 1.0000e-04  eta: 2:07:37  time: 0.5840  data_time: 0.0012  memory: 10877  loss: 0.0900
# 11/18 11:12:36 - mmengine - INFO - Epoch(train)  [5][200/241]  lr: 1.0000e-04  eta: 2:04:41  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0888
# 11/18 11:13:00 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:13:37 - mmengine - INFO - Epoch(val) [5][35/35]    accuracy/top1: 97.7113  confusion_matrix/result:
# tensor([[  38,   19,    0,    0,    0,    1],
#         [   3,   29,    0,    0,    0,    1],
#         [   0,    3,   20,    4,    0,    0],
#         [   0,    0,    1,   15,    0,    0],
#         [   0,    1,    0,    0, 4171,   10],
#         [   5,    2,    0,    0,   51,   39]])
#   data_time: 0.8753  time: 1.0569
# 11/18 11:14:36 - mmengine - INFO - Epoch(train)  [6][100/241]  lr: 1.0000e-04  eta: 2:01:04  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0959
# 11/18 11:15:34 - mmengine - INFO - Epoch(train)  [6][200/241]  lr: 1.0000e-04  eta: 1:58:47  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0816
# 11/18 11:15:58 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:16:57 - mmengine - INFO - Epoch(train)  [7][100/241]  lr: 1.0000e-04  eta: 1:55:49  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0875
# 11/18 11:17:55 - mmengine - INFO - Epoch(train)  [7][200/241]  lr: 1.0000e-04  eta: 1:53:54  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0789
# 11/18 11:18:19 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:19:17 - mmengine - INFO - Epoch(train)  [8][100/241]  lr: 1.0000e-04  eta: 1:51:22  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0703
# 11/18 11:20:16 - mmengine - INFO - Epoch(train)  [8][200/241]  lr: 1.0000e-04  eta: 1:49:41  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0917
# 11/18 11:20:39 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:21:21 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:21:38 - mmengine - INFO - Epoch(train)  [9][100/241]  lr: 1.0000e-04  eta: 1:47:24  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.1050
# 11/18 11:22:36 - mmengine - INFO - Epoch(train)  [9][200/241]  lr: 1.0000e-04  eta: 1:45:52  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0683
# 11/18 11:23:00 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:23:58 - mmengine - INFO - Epoch(train) [10][100/241]  lr: 1.0000e-04  eta: 1:43:47  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0775
# 11/18 11:24:57 - mmengine - INFO - Epoch(train) [10][200/241]  lr: 1.0000e-04  eta: 1:42:22  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0699
# 11/18 11:25:20 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:25:20 - mmengine - INFO - Saving checkpoint at 10 epochs
# 11/18 11:25:32 - mmengine - INFO - Epoch(val) [10][35/35]    accuracy/top1: 97.7566  confusion_matrix/result:
# tensor([[  44,    5,    3,    0,    1,    5],
#         [  10,   17,    2,    0,    1,    3],
#         [   0,    2,   24,    0,    0,    1],
#         [   0,    0,    1,   15,    0,    0],
#         [   2,    0,    0,    0, 4175,    5],
#         [   2,    1,    0,    0,   55,   39]])
#   data_time: 0.1227  time: 0.3014
# 11/18 11:26:31 - mmengine - INFO - Epoch(train) [11][100/241]  lr: 1.0000e-04  eta: 1:40:25  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0889
# 11/18 11:27:29 - mmengine - INFO - Epoch(train) [11][200/241]  lr: 1.0000e-04  eta: 1:39:05  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0717
# 11/18 11:27:53 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:28:52 - mmengine - INFO - Epoch(train) [12][100/241]  lr: 1.0000e-04  eta: 1:37:13  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0616
# 11/18 11:29:50 - mmengine - INFO - Epoch(train) [12][200/241]  lr: 1.0000e-04  eta: 1:35:57  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0731
# 11/18 11:30:13 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:31:12 - mmengine - INFO - Epoch(train) [13][100/241]  lr: 1.0000e-04  eta: 1:34:10  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0811
# 11/18 11:31:17 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:32:11 - mmengine - INFO - Epoch(train) [13][200/241]  lr: 1.0000e-04  eta: 1:32:56  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0928
# 11/18 11:32:34 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:33:33 - mmengine - INFO - Epoch(train) [14][100/241]  lr: 1.0000e-04  eta: 1:31:13  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0672
# 11/18 11:34:31 - mmengine - INFO - Epoch(train) [14][200/241]  lr: 1.0000e-04  eta: 1:30:02  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0603
# 11/18 11:34:55 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:35:53 - mmengine - INFO - Epoch(train) [15][100/241]  lr: 1.0000e-04  eta: 1:28:22  time: 0.5840  data_time: 0.0012  memory: 10877  loss: 0.0663
# 11/18 11:36:52 - mmengine - INFO - Epoch(train) [15][200/241]  lr: 1.0000e-04  eta: 1:27:12  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0772
# 11/18 11:37:15 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:37:26 - mmengine - INFO - Epoch(val) [15][35/35]    accuracy/top1: 97.7566  confusion_matrix/result:
# tensor([[  52,    5,    0,    0,    0,    1],
#         [  19,   14,    0,    0,    0,    0],
#         [   0,    2,   20,    3,    0,    2],
#         [   0,    0,    1,   14,    1,    0],
#         [   3,    1,    0,    0, 4166,   12],
#         [   6,    0,    0,    0,   43,   48]])
#   data_time: 0.0981  time: 0.2766
# 11/18 11:38:25 - mmengine - INFO - Epoch(train) [16][100/241]  lr: 1.0000e-04  eta: 1:25:34  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0678
# 11/18 11:39:23 - mmengine - INFO - Epoch(train) [16][200/241]  lr: 1.0000e-04  eta: 1:24:25  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0908
# 11/18 11:39:47 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:40:45 - mmengine - INFO - Epoch(train) [17][100/241]  lr: 1.0000e-04  eta: 1:22:49  time: 0.5844  data_time: 0.0014  memory: 10877  loss: 0.0712
# 11/18 11:41:11 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:41:44 - mmengine - INFO - Epoch(train) [17][200/241]  lr: 1.0000e-04  eta: 1:21:42  time: 0.5838  data_time: 0.0012  memory: 10877  loss: 0.0725
# 11/18 11:42:07 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:43:06 - mmengine - INFO - Epoch(train) [18][100/241]  lr: 1.0000e-04  eta: 1:20:07  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0944
# 11/18 11:44:04 - mmengine - INFO - Epoch(train) [18][200/241]  lr: 1.0000e-04  eta: 1:19:01  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0543
# 11/18 11:44:28 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:45:26 - mmengine - INFO - Epoch(train) [19][100/241]  lr: 1.0000e-04  eta: 1:17:28  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0752
# 11/18 11:46:25 - mmengine - INFO - Epoch(train) [19][200/241]  lr: 1.0000e-04  eta: 1:16:23  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0775
# 11/18 11:46:48 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:47:47 - mmengine - INFO - Epoch(train) [20][100/241]  lr: 1.0000e-04  eta: 1:14:50  time: 0.5845  data_time: 0.0013  memory: 10877  loss: 0.0609
# 11/18 11:48:45 - mmengine - INFO - Epoch(train) [20][200/241]  lr: 1.0000e-04  eta: 1:13:46  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0577
# 11/18 11:49:09 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:49:09 - mmengine - INFO - Saving checkpoint at 20 epochs
# 11/18 11:49:20 - mmengine - INFO - Epoch(val) [20][35/35]    accuracy/top1: 97.7566  confusion_matrix/result:
# tensor([[  49,    7,    0,    0,    1,    1],
#         [  10,   23,    0,    0,    0,    0],
#         [   0,    2,   24,    1,    0,    0],
#         [   0,    0,    2,   14,    0,    0],
#         [   2,    0,    0,    0, 4179,    1],
#         [   3,    0,    0,    0,   69,   25]])
#   data_time: 0.1021  time: 0.2805
# 11/18 11:50:19 - mmengine - INFO - Epoch(train) [21][100/241]  lr: 1.0000e-04  eta: 1:12:15  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0667
# 11/18 11:51:06 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:51:17 - mmengine - INFO - Epoch(train) [21][200/241]  lr: 1.0000e-04  eta: 1:11:10  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0861
# 11/18 11:51:41 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:52:40 - mmengine - INFO - Epoch(train) [22][100/241]  lr: 1.0000e-04  eta: 1:09:40  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0588
# 11/18 11:53:38 - mmengine - INFO - Epoch(train) [22][200/241]  lr: 1.0000e-04  eta: 1:08:37  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0593
# 11/18 11:54:02 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:55:00 - mmengine - INFO - Epoch(train) [23][100/241]  lr: 1.0000e-04  eta: 1:07:07  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0478
# 11/18 11:55:59 - mmengine - INFO - Epoch(train) [23][200/241]  lr: 1.0000e-04  eta: 1:06:04  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0815
# 11/18 11:56:22 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:57:21 - mmengine - INFO - Epoch(train) [24][100/241]  lr: 1.0000e-04  eta: 1:04:35  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0845
# 11/18 11:58:19 - mmengine - INFO - Epoch(train) [24][200/241]  lr: 1.0000e-04  eta: 1:03:32  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0697
# 11/18 11:58:43 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 11:59:41 - mmengine - INFO - Epoch(train) [25][100/241]  lr: 1.0000e-04  eta: 1:02:04  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0618
# 11/18 12:00:40 - mmengine - INFO - Epoch(train) [25][200/241]  lr: 1.0000e-04  eta: 1:01:01  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0570
# 11/18 12:00:49 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:01:03 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:01:13 - mmengine - INFO - Epoch(val) [25][35/35]    accuracy/top1: 97.6887  confusion_matrix/result:
# tensor([[  35,   21,    0,    0,    1,    1],
#         [   2,   30,    0,    0,    0,    1],
#         [   0,    2,   20,    5,    0,    0],
#         [   0,    0,    0,   16,    0,    0],
#         [   1,    1,    0,    0, 4172,    8],
#         [   2,    1,    0,    0,   56,   38]])
#   data_time: 0.0781  time: 0.2567
# 11/18 12:02:11 - mmengine - INFO - Epoch(train) [26][100/241]  lr: 1.0000e-05  eta: 0:59:33  time: 0.5838  data_time: 0.0012  memory: 10877  loss: 0.0491
# 11/18 12:03:10 - mmengine - INFO - Epoch(train) [26][200/241]  lr: 1.0000e-05  eta: 0:58:31  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0382
# 11/18 12:03:33 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:04:32 - mmengine - INFO - Epoch(train) [27][100/241]  lr: 1.0000e-05  eta: 0:57:04  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0362
# 11/18 12:07:00 - mmengine - INFO - Epoch(train) [27][200/241]  lr: 1.0000e-05  eta: 0:57:19  time: 1.2873  data_time: 0.7047  memory: 10877  loss: 0.0483
# 11/18 12:07:58 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:09:30 - mmengine - INFO - Epoch(train) [28][100/241]  lr: 1.0000e-05  eta: 0:56:44  time: 0.8461  data_time: 0.2635  memory: 10877  loss: 0.0533
# 11/18 12:10:58 - mmengine - INFO - Epoch(train) [28][200/241]  lr: 1.0000e-05  eta: 0:56:02  time: 0.7174  data_time: 0.1349  memory: 10877  loss: 0.0441
# 11/18 12:11:33 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:12:32 - mmengine - INFO - Epoch(train) [29][100/241]  lr: 1.0000e-05  eta: 0:54:37  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0449
# 11/18 12:13:30 - mmengine - INFO - Epoch(train) [29][200/241]  lr: 1.0000e-05  eta: 0:53:31  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0460
# 11/18 12:13:54 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:14:00 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:14:52 - mmengine - INFO - Epoch(train) [30][100/241]  lr: 1.0000e-05  eta: 0:51:57  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0424
# 11/18 12:15:51 - mmengine - INFO - Epoch(train) [30][200/241]  lr: 1.0000e-05  eta: 0:50:51  time: 0.5838  data_time: 0.0012  memory: 10877  loss: 0.0656
# 11/18 12:16:14 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:16:14 - mmengine - INFO - Saving checkpoint at 30 epochs
# 11/18 12:17:26 - mmengine - INFO - Epoch(val) [30][35/35]    accuracy/top1: 98.0059  confusion_matrix/result:
# tensor([[  43,   14,    0,    0,    0,    1],
#         [   4,   28,    0,    0,    0,    1],
#         [   0,    2,   22,    2,    1,    0],
#         [   0,    0,    1,   15,    0,    0],
#         [   2,    0,    0,    0, 4170,   10],
#         [   2,    1,    0,    0,   47,   47]])
#   data_time: 1.7850  time: 1.9636
# 11/18 12:18:25 - mmengine - INFO - Epoch(train) [31][100/241]  lr: 1.0000e-05  eta: 0:49:19  time: 0.5840  data_time: 0.0012  memory: 10877  loss: 0.0743
# 11/18 12:19:24 - mmengine - INFO - Epoch(train) [31][200/241]  lr: 1.0000e-05  eta: 0:48:13  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0631
# 11/18 12:19:47 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:20:46 - mmengine - INFO - Epoch(train) [32][100/241]  lr: 1.0000e-05  eta: 0:46:41  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0372
# 11/18 12:21:44 - mmengine - INFO - Epoch(train) [32][200/241]  lr: 1.0000e-05  eta: 0:45:37  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0509
# 11/18 12:22:08 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:23:06 - mmengine - INFO - Epoch(train) [33][100/241]  lr: 1.0000e-05  eta: 0:44:05  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0476
# 11/18 12:24:05 - mmengine - INFO - Epoch(train) [33][200/241]  lr: 1.0000e-05  eta: 0:43:01  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0601
# 11/18 12:24:28 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:24:56 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:25:27 - mmengine - INFO - Epoch(train) [34][100/241]  lr: 1.0000e-05  eta: 0:41:30  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0588
# 11/18 12:26:25 - mmengine - INFO - Epoch(train) [34][200/241]  lr: 1.0000e-05  eta: 0:40:26  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0429
# 11/18 12:26:49 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:27:48 - mmengine - INFO - Epoch(train) [35][100/241]  lr: 1.0000e-05  eta: 0:38:55  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0656
# 11/18 12:28:46 - mmengine - INFO - Epoch(train) [35][200/241]  lr: 1.0000e-05  eta: 0:37:52  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0363
# 11/18 12:29:09 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:29:19 - mmengine - INFO - Epoch(val) [35][35/35]    accuracy/top1: 98.0059  confusion_matrix/result:
# tensor([[  46,   11,    0,    0,    0,    1],
#         [   6,   26,    0,    0,    0,    1],
#         [   0,    2,   22,    2,    1,    0],
#         [   0,    0,    1,   15,    0,    0],
#         [   2,    0,    0,    0, 4163,   17],
#         [   1,    1,    0,    0,   42,   53]])
#   data_time: 0.1040  time: 0.2824
# 11/18 12:30:18 - mmengine - INFO - Epoch(train) [36][100/241]  lr: 1.0000e-05  eta: 0:36:22  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0538
# 11/18 12:31:16 - mmengine - INFO - Epoch(train) [36][200/241]  lr: 1.0000e-05  eta: 0:35:18  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0447
# 11/18 12:31:40 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:32:39 - mmengine - INFO - Epoch(train) [37][100/241]  lr: 1.0000e-05  eta: 0:33:49  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0466
# 11/18 12:33:37 - mmengine - INFO - Epoch(train) [37][200/241]  lr: 1.0000e-05  eta: 0:32:45  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0623
# 11/18 12:34:01 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:34:49 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:34:59 - mmengine - INFO - Epoch(train) [38][100/241]  lr: 1.0000e-05  eta: 0:31:16  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0645
# 11/18 12:35:58 - mmengine - INFO - Epoch(train) [38][200/241]  lr: 1.0000e-05  eta: 0:30:13  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0593
# 11/18 12:36:21 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:37:20 - mmengine - INFO - Epoch(train) [39][100/241]  lr: 1.0000e-05  eta: 0:28:45  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0372
# 11/18 12:38:18 - mmengine - INFO - Epoch(train) [39][200/241]  lr: 1.0000e-05  eta: 0:27:42  time: 0.5838  data_time: 0.0012  memory: 10877  loss: 0.0502
# 11/18 12:38:42 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:39:40 - mmengine - INFO - Epoch(train) [40][100/241]  lr: 1.0000e-05  eta: 0:26:13  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0379
# 11/18 12:40:39 - mmengine - INFO - Epoch(train) [40][200/241]  lr: 1.0000e-05  eta: 0:25:11  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0490
# 11/18 12:41:02 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:41:02 - mmengine - INFO - Saving checkpoint at 40 epochs
# 11/18 12:41:13 - mmengine - INFO - Epoch(val) [40][35/35]    accuracy/top1: 98.0286  confusion_matrix/result:
# tensor([[  47,   10,    0,    0,    0,    1],
#         [   8,   24,    0,    0,    0,    1],
#         [   0,    2,   22,    3,    0,    0],
#         [   0,    0,    0,   16,    0,    0],
#         [   2,    0,    0,    0, 4167,   13],
#         [   1,    1,    0,    0,   45,   50]])
#   data_time: 0.0814  time: 0.2598
# 11/18 12:42:12 - mmengine - INFO - Epoch(train) [41][100/241]  lr: 1.0000e-05  eta: 0:23:43  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0446
# 11/18 12:43:10 - mmengine - INFO - Epoch(train) [41][200/241]  lr: 1.0000e-05  eta: 0:22:41  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0593
# 11/18 12:43:34 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:44:32 - mmengine - INFO - Epoch(train) [42][100/241]  lr: 1.0000e-05  eta: 0:21:13  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0537
# 11/18 12:44:43 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:45:31 - mmengine - INFO - Epoch(train) [42][200/241]  lr: 1.0000e-05  eta: 0:20:11  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0427
# 11/18 12:45:54 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:46:53 - mmengine - INFO - Epoch(train) [43][100/241]  lr: 1.0000e-05  eta: 0:18:43  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0303
# 11/18 12:47:51 - mmengine - INFO - Epoch(train) [43][200/241]  lr: 1.0000e-05  eta: 0:17:41  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0451
# 11/18 12:48:15 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:49:13 - mmengine - INFO - Epoch(train) [44][100/241]  lr: 1.0000e-05  eta: 0:16:14  time: 0.5843  data_time: 0.0013  memory: 10877  loss: 0.0488
# 11/18 12:50:12 - mmengine - INFO - Epoch(train) [44][200/241]  lr: 1.0000e-05  eta: 0:15:12  time: 0.5843  data_time: 0.0014  memory: 10877  loss: 0.0420
# 11/18 12:50:35 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:51:34 - mmengine - INFO - Epoch(train) [45][100/241]  lr: 1.0000e-05  eta: 0:13:45  time: 0.5839  data_time: 0.0012  memory: 10877  loss: 0.0393
# 11/18 12:52:32 - mmengine - INFO - Epoch(train) [45][200/241]  lr: 1.0000e-05  eta: 0:12:43  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0528
# 11/18 12:52:56 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:53:04 - mmengine - INFO - Epoch(val) [45][35/35]    accuracy/top1: 97.8699  confusion_matrix/result:
# tensor([[  49,    8,    0,    0,    0,    1],
#         [   8,   24,    0,    0,    0,    1],
#         [   0,    2,   22,    2,    1,    0],
#         [   0,    0,    1,   15,    0,    0],
#         [   2,    0,    0,    0, 4161,   19],
#         [   3,    1,    0,    0,   45,   48]])
#   data_time: 0.0468  time: 0.2251
# 11/18 12:54:03 - mmengine - INFO - Epoch(train) [46][100/241]  lr: 1.0000e-05  eta: 0:11:16  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0301
# 11/18 12:54:35 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:55:01 - mmengine - INFO - Epoch(train) [46][200/241]  lr: 1.0000e-05  eta: 0:10:15  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0331
# 11/18 12:55:25 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:56:23 - mmengine - INFO - Epoch(train) [47][100/241]  lr: 1.0000e-05  eta: 0:08:48  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0584
# 11/18 12:57:22 - mmengine - INFO - Epoch(train) [47][200/241]  lr: 1.0000e-05  eta: 0:07:47  time: 0.5842  data_time: 0.0014  memory: 10877  loss: 0.0553
# 11/18 12:57:45 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 12:58:44 - mmengine - INFO - Epoch(train) [48][100/241]  lr: 1.0000e-05  eta: 0:06:20  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0331
# 11/18 12:59:42 - mmengine - INFO - Epoch(train) [48][200/241]  lr: 1.0000e-05  eta: 0:05:19  time: 0.5840  data_time: 0.0013  memory: 10877  loss: 0.0398
# 11/18 13:00:06 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 13:01:05 - mmengine - INFO - Epoch(train) [49][100/241]  lr: 1.0000e-05  eta: 0:03:53  time: 0.5840  data_time: 0.0012  memory: 10877  loss: 0.0473
# 11/18 13:02:03 - mmengine - INFO - Epoch(train) [49][200/241]  lr: 1.0000e-05  eta: 0:02:52  time: 0.5839  data_time: 0.0013  memory: 10877  loss: 0.0462
# 11/18 13:02:27 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 13:03:25 - mmengine - INFO - Epoch(train) [50][100/241]  lr: 1.0000e-05  eta: 0:01:26  time: 0.5842  data_time: 0.0013  memory: 10877  loss: 0.0458
# 11/18 13:04:18 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 13:04:24 - mmengine - INFO - Epoch(train) [50][200/241]  lr: 1.0000e-05  eta: 0:00:25  time: 0.5841  data_time: 0.0013  memory: 10877  loss: 0.0340
# 11/18 13:04:47 - mmengine - INFO - Exp name: baseline1_ourdata_mmpretrain_kaggle_Nov18_20241118_105848
# 11/18 13:04:47 - mmengine - INFO - Saving checkpoint at 50 epochs
# 11/18 13:05:00 - mmengine - INFO - Epoch(val) [50][35/35]    accuracy/top1: 97.8473  confusion_matrix/result:
# tensor([[  48,    9,    0,    0,    0,    1],
#         [   7,   25,    0,    0,    0,    1],
#         [   0,    2,   21,    3,    1,    0],
#         [   0,    0,    2,   14,    0,    0],
#         [   2,    0,    0,    0, 4163,   17],
#         [   2,    1,    0,    0,   47,   47]])
#   data_time: 0.1328  time: 0.3113

# %%
# !python tools/test.py /kaggle/input/configs-file/original_openmm_kaggle_Nov18.py /kaggle/working/experiment_result/epoch_50.pth
# Out:
# /opt/conda/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.2.1) or chardet (None)/charset_normalizer (3.3.2) doesn't match a supported version!
#   warnings.warn(
# 11/18 13:05:18 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1348522418
#     GPU 0: Tesla P100-PCIE-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.3, V12.3.107
#     GCC: gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.2+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.2, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.2+cu121
#     OpenCV: 4.10.0
#     MMEngine: 0.10.5
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1348522418
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 11/18 13:05:19 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=256)
# batch_size = 128
# data_preprocessor = dict(
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     to_rgb=True)
# data_root = '/kaggle/input/malaria-parasite/final_malaria_full_class_classification_cropped'
# default_hooks = dict(
#     checkpoint=dict(by_epoch=True, interval=10, type='CheckpointHook'),
#     logger=dict(interval=100, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(enable=False, type='VisualizationHook'))
# default_scope = 'mmpretrain'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(interval=1)
# launcher = 'none'
# load_from = '/kaggle/working/experiment_result/epoch_50.pth'
# log_level = 'INFO'
# model = dict(
#     backbone=dict(
#         depth=50,
#         init_cfg=dict(
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/resnet/resnet50_8xb32_in1k_20210831-ea4938fc.pth',
#             prefix='backbone',
#             type='Pretrained'),
#         num_stages=4,
#         out_indices=(3, ),
#         style='pytorch',
#         type='ResNet'),
#     head=dict(
#         in_channels=2048,
#         loss=dict(loss_weight=1.0, type='CrossEntropyLoss'),
#         num_classes=6,
#         topk=(
#             1,
#             5,
#         ),
#         type='LinearClsHead'),
#     neck=dict(type='GlobalAveragePooling'),
#     type='ImageClassifier')
# optim_wrapper = dict(
#     clip_grad=None,
#     optimizer=dict(lr=0.0001, type='Adam', weight_decay=0.0001),
#     type='OptimWrapper')
# optimizer = dict(_delete_=True, lr=0.0001, type='Adam', weight_decay=0.0001)
# out = '/kaggle/working/test_result'
# param_scheduler = dict(
#     by_epoch=True, gamma=0.1, milestones=[
#         40,
#     ], type='MultiStepLR')
# randomness = dict(deterministic=False, seed=None)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=128,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file='test_annotation.txt',
#         data_prefix='',
#         data_root=
#         '/kaggle/input/malaria-parasite/final_malaria_full_class_classification_cropped',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=224, type='RandomResizedCrop'),
#             dict(type='PackInputs'),
#         ],
#         type='CustomDataset',
#         with_label=True),
#     num_workers=1,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# test_evaluator = dict(type='ConfusionMatrix')
# train_cfg = dict(max_epochs=10, type='EpochBasedTrainLoop', val_interval=1)
# train_dataloader = dict(
#     batch_size=128,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file='train_annotation.txt',
#         data_prefix='',
#         data_root=
#         '/kaggle/input/malaria-parasite/final_malaria_full_class_classification_cropped',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=224, type='RandomResizedCrop'),
#             dict(type='PackInputs'),
#         ],
#         type='CustomDataset',
#         with_label=True),
#     num_workers=1,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(scale=224, type='RandomResizedCrop'),
#     dict(type='PackInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=128,
#     collate_fn=dict(type='default_collate'),
#     dataset=dict(
#         ann_file='val_annotation.txt',
#         data_prefix='',
#         data_root=
#         '/kaggle/input/malaria-parasite/final_malaria_full_class_classification_cropped',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(scale=224, type='RandomResizedCrop'),
#             dict(type='PackInputs'),
#         ],
#         type='CustomDataset',
#         with_label=True),
#     num_workers=1,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# val_evaluator = dict(type='Accuracy')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='Visualizer', vis_backends=[
#         dict(type='TensorboardVisBackend'),
#     ])
# work_dir = '/kaggle/working/experiment_result'
#
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.21 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# 11/18 13:05:26 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 11/18 13:05:26 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) VisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# Loads checkpoint by local backend from path: /kaggle/working/experiment_result/epoch_50.pth
# 11/18 13:05:28 - mmengine - INFO - Load checkpoint from /kaggle/working/experiment_result/epoch_50.pth
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 11/18 13:07:53 - mmengine - INFO - Epoch(test) [71/71]    confusion_matrix/result:
# tensor([[  85,   20,    1,    0,    9,    3],
#         [  13,   41,    0,    0,    4,    1],
#         [   0,    1,   52,    4,    2,    0],
#         [   0,    2,    6,   36,    1,    0],
#         [   4,    0,    2,    1, 8518,   38],
#         [   5,    1,    0,    0,  106,   71]])
#   data_time: 2.0096  time: 2.0337
